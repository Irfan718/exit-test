# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('/content/train_exit.csv')

# %% [markdown]
# Load Data set to python

# %%
data
# Out:
#         player_id                 name  age gender    country height  weight  \
# 0       PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1      PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2      PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3      PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4       PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
# ...           ...                  ...  ...    ...        ...    ...     ...
# 13989  PLID_10956         Viva Stepney   20      M    Uruguay    6'0  161lbs
# 13990  PLID_17290           Illa Pitre   18      F    England   5'10  165lbs
# 13991   PLID_5193    Marylouise Mosley   17      M      Japan    6'0  172lbs
# 13992  PLID_12173       Teri Escamilla   20      F    Ukraine   5'10  150lbs
# 13993    PLID_236       Darius Schuman   16      F      Chile    5'8  159lbs
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         player_id                 name  age gender    country height  weight  \
# 0       PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1      PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2      PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3      PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4       PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
# ...           ...                  ...  ...    ...        ...    ...     ...
# 13989  PLID_10956         Viva Stepney   20      M    Uruguay    6'0  161lbs
# 13990  PLID_17290           Illa Pitre   18      F    England   5'10  165lbs
# 13991   PLID_5193    Marylouise Mosley   17      M      Japan    6'0  172lbs
# 13992  PLID_12173       Teri Escamilla   20      F    Ukraine   5'10  150lbs
# 13993    PLID_236       Darius Schuman   16      F      Chile    5'8  159lbs
#
# ...

# %%
data.shape
# Out:
# (13994, 30)

# %%
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
# prompt: Using dataframe data:

data = pd.DataFrame({'name': ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
                   'age': [20, 25, 30, 35, 40]})

# %%
# prompt: supervised learning

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['age']], data['name'], test_size=0.25)

# %%
# prompt: Using dataframe X_test: from sklearn.model_selection import train_test_split X_train, X_test, y_train, y_test = train_test_split(data[['age']], data['name'], test_size=0.25)

X_test

# %%
# prompt: Using dataframe X_train:

X_train.describe()
# Out:
#              age
# count   3.000000
# mean   31.666667
# std     7.637626
# min    25.000000
# 25%    27.500000
# 50%    30.000000
# 75%    35.000000
# max    40.000000

# %%
# prompt: outlier detection

sns.boxplot(x=X_train['age'])
# Out:
# <Axes: xlabel='age'>

# %%
# prompt: handling outlier

X_train = X_train.loc[(X_train['age'] < X_train['age'].quantile(0.975))]

# %%
# prompt: minmax scaling

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train[['age']] = scaler.fit_transform(X_train[['age']])
X_test[['age']] = scaler.transform(X_test[['age']])

# %%
data.head
# Out:
# <bound method NDFrame.head of     name  age
# 0  Alice   20
# 1    Bob   25
# 2  Carol   30
# 3   Dave   35
# 4    Eve   40>
